# %% [markdown]
# # **Binary Classification of Insurance Cross Selling**

# %% [markdown]
# In this analysis, we are developing a model for binary classification in the field of insurance cross-selling. The goal is to determine the likelihood that a customer is interested in an additional insurance product. To achieve this, we will employ various classification algorithms to attain the best possible prediction accuracy.
#
# We plan to evaluate multiple models, including Light Gradient Boosting Machine, Gradient Boosting Classifier, Ada Boost Classifier, and Random Forest. These models will be assessed using metrics such as accuracy, AUC, recall, precision, F1-score, Kappa, and MCC. Through this comparison, we aim to gain a comprehensive understanding of the strengths and weaknesses of each algorithm and identify which model is most suitable for identifying potential cross-sales.

# %% [markdown]
# **Data Dictionary**
#
# | Column Name             | Description                                       | Turkish Translation                          |
# |-------------------------|---------------------------------------------------|----------------------------------------------|
# | ID                      | Unique identifier for the individual               | Birey için benzersiz kimlik                 |
# | Gender                  | Gender of the individual                           | Bireyin cinsiyeti                            |
# | Age                     | Age of the individual                              | Bireyin yaşı                                 |
# | Driving License         | Indicates if the individual has a driving license  | Bireyin sürücü belgesinin olup olmadığını belirtir |
# | Region Code             | Code representing the region                       | Bölgeyi temsil eden kod                      |
# | Previously Insured      | Indicates if the individual was previously insured | Bireyin daha önce sigortalı olup olmadığını belirtir |
# | Vehicle Age             | Age of the vehicle                                 | Araç yaşı                                    |
# | Vehicle Damage          | Indicates if the vehicle has sustained damage      | Araçta hasar olup olmadığını belirtir        |
# | Annual Premium          | Annual insurance premium amount                    | Yıllık sigorta prim tutarı                   |
# | Policy Sales Channel    | Channel through which the policy was sold         | Poliçenin satıldığı kanal                    |
# | Vintage                 | Time since the policy was issued                   | Poliçenin düzenlendiği süre                  |
# | Response                | Indicates if the individual responded              | Bireyin yanıt verip vermediğini belirtir    |

# %% [markdown]
# <img src='https://pfst.cf2.poecdn.net/base/image/33d6b5db3db39301f6ad6e6a95a607aa282e4977960cf405f1cae653c48414de?w=1024&h=768&pmaid=259373161' width='800'>
# <a href='https://www.kaggle.com/datasets/bhavikjikadara/car-price-prediction-dataset' target=_blank>
# Click here for the dataset </a>

# %% [markdown]
# **Import library**

# %%
#!pip install pycaret

# %%
import pandas as pd
from pycaret.classification import*

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Load the data**

# %%
test=pd.read_csv('test.csv')
train=pd.read_csv('train.csv')

# %%
df = pd.concat([test, train], ignore_index=True)

# %% [markdown]
# **EDA - Exploratory Data Analysis**

# %%
df.head()
# Out:
#          id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  11504798  Female   20                1         47.0                 0.0
# 1  11504799    Male   47                1         28.0                 0.0
# 2  11504800    Male   47                1         43.0                 0.0
# 3  11504801  Female   22                1         47.0                 1.0
# 4  11504802    Male   51                1         19.0                 0.0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    < 1 Year             No          2630.0                 160.0    228.0
# 1    1-2 Year            Yes         37483.0                 124.0    123.0
# 2    1-2 Year            Yes          2630.0                  26.0    271.0
# 3    < 1 Year             No         24502.0                 152.0    115.0
# 4    1-2 Year             No         34115.0                 124.0    148.0
#
#    Response
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df.shape
# Out:
# (706274, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706274 entries, 0 to 706273
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    706274 non-null  int64
#  1   Gender                706274 non-null  object
#  2   Age                   706274 non-null  int64
#  3   Driving_License       706274 non-null  int64
#  4   Region_Code           706274 non-null  float64
#  5   Previously_Insured    706273 non-null  float64
#  6   Vehicle_Age           706273 non-null  object
#  7   Vehicle_Damage        706273 non-null  object
#  8   Annual_Premium        706273 non-null  float64
#  9   Policy_Sales_Channel  706273 non-null  float64
#  10  Vintage               706273 non-null  float64
#  11  Response              298515 non-null  float64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 64.7+ MB

# %%
df.isnull().sum()
# Out:
# id                           0
# Gender                       0
# Age                          0
# Driving_License              0
# Region_Code                  0
# Previously_Insured           1
# Vehicle_Age                  1
# Vehicle_Damage               1
# Annual_Premium               1
# Policy_Sales_Channel         1
# Vintage                      1
# Response                407759
# dtype: int64

# %% [markdown]
# **Data Preparation**

# %%
# Check for missing values in the target variable
missing_values = df['Response'].isna().sum()
print(f"Missing values in the target variable: {missing_values}")

# Remove rows with missing values in the target variable
df = df.dropna(subset=['Response'])
# Out:
# Missing values in the target variable: 407759

# %%
# Set up the PyCaret environment
clf = setup(data=df, target='Response', session_id=123,
            categorical_features=['Gender', 'Driving_License', 'Region_Code', 'Vehicle_Age', 'Vehicle_Damage', 'Policy_Sales_Channel'],
            numeric_features=['Age', 'Annual_Premium', 'Vintage'],
            ignore_features=['id'])
# Out:
# <style type="text/css">
# #T_d1554_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d1554" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1554_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d1554_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1554_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1554_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d1554_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d1554_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d1554_row1_col1" class="data row1 col1" >Response</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d1554_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d1554_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d1554_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d1554_row3_col1" class="data row3 col1" >(298515, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d1554_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d1554_row4_col1" class="data row4 col1" >(298515, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d1554_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d1554_row5_col1" class="data row5 col1" >(208960, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d1554_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d1554_row6_col1" class="data row6 col1" >(89555, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d1554_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_d1554_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d1554_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_d1554_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d1554_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_d1554_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d1554_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_d1554_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d1554_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_d1554_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d1554_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_d1554_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d1554_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_d1554_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d1554_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_d1554_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d1554_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_d1554_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d1554_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_d1554_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d1554_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_d1554_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d1554_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_d1554_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d1554_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_d1554_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d1554_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_d1554_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d1554_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_d1554_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d1554_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d1554_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_d1554_row22_col1" class="data row22 col1" >4b64</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Compare models
best_model = compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         08:52:44
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_66759 th {
#   text-align: left;
# }
# #T_66759_row0_col0, #T_66759_row0_col1, #T_66759_row0_col2, #T_66759_row0_col3, #T_66759_row0_col4, #T_66759_row0_col5, #T_66759_row0_col6, #T_66759_row0_col7, #T_66759_row0_col8, #T_66759_row1_col0, #T_66759_row1_col1, #T_66759_row1_col2, #T_66759_row1_col3, #T_66759_row1_col4, #T_66759_row1_col5, #T_66759_row1_col6, #T_66759_row1_col7, #T_66759_row1_col8, #T_66759_row2_col0, #T_66759_row2_col1, #T_66759_row2_col2, #T_66759_row2_col3, #T_66759_row2_col4, #T_66759_row2_col5, #T_66759_row2_col6
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# <style type="text/css">
# #T_ebbcc th {
#   text-align: left;
# }
# #T_ebbcc_row0_col0, #T_ebbcc_row0_col3, #T_ebbcc_row0_col5, #T_ebbcc_row0_col6, #T_ebbcc_row0_col7, #T_ebbcc_row1_col0, #T_ebbcc_row1_col1, #T_ebbcc_row1_col2, #T_ebbcc_row1_col3, #T_ebbcc_row1_col4, #T_ebbcc_row1_col5, #T_ebbcc_row1_col6, #T_ebbcc_row1_col7, #T_ebbcc_row2_col0, #T_ebbcc_row2_col1, #T_ebbcc_row2_col2, #T_ebbcc_row2_col3, #T_ebbcc_row2_col4, #T_ebbcc_row2_col5, #T_ebbcc_row2_col6, #T_ebbcc_row2_col7, #T_ebbcc_row3_col0, #T_ebbcc_row3_col1, #T_ebbcc_row3_col2, #T_ebbcc_row3_col3, #T_ebbcc_row3_col4, #T_ebbcc_row3_col5, #T_ebbcc_row3_col6, #T_ebbcc_row3_col7, #T_ebbcc_row4_col0, #T_ebbcc_row4_col1, #T_ebbcc_row4_col2, #T_ebbcc_row4_col3, #T_ebbcc_row4_col4, #T_ebbcc_row4_col5, #T_ebbcc_row4_col6, #T_ebbcc_row4_col7, #T_ebbcc_row5_col0, #T_ebbcc_row5_col1, #T_ebbcc_row5_col2, #T_ebbcc_row5_col3, #T_ebbcc_row5_col4, #T_ebbcc_row5_col5, #T_ebbcc_row5_col6, #T_ebbcc_row5_col7, #T_ebbcc_row6_col0, #T_ebbcc_row6_col1, #T_ebbcc_row6_col2, #T_ebbcc_row6_col3, #T_ebbcc_row6_col4, #T_ebbcc_row6_col5, #T_ebbcc_row6_col6, #T_ebbcc_row6_col7, #T_ebbcc_row7_col0, #T_ebbcc_row7_col1, #T_ebbcc_row7_col2, #T_ebbcc_row7_col3, #T_ebbcc_row7_col4, #T_ebbcc_row7_col5, #T_ebbcc_row7_col6, #T_ebbcc_row7_col7, #T_ebbcc_row8_col0, #T_ebbcc_row8_col1, #T_ebbcc_row8_col2, #T_ebbcc_row8_col3, #T_ebbcc_row8_col4, #T_ebbcc_row8_col5, #T_ebbcc_row8_col6, #T_ebbcc_row8_col7, #T_ebbcc_row9_col0, #T_ebbcc_row9_col1, #T_ebbcc_row9_col2, #T_ebbcc_row9_col3, #T_ebbcc_row9_col4, #T_ebbcc_row9_col5, #T_ebbcc_row9_col6, #T_ebbcc_row9_col7, #T_ebbcc_row10_col0, #T_ebbcc_row10_col1, #T_ebbcc_row10_col2, #T_ebbcc_row10_col3, #T_ebbcc_row10_col4, #T_ebbcc_row10_col5, #T_ebbcc_row10_col6, #T_ebbcc_row10_col7, #T_ebbcc_row11_col0, #T_ebbcc_row11_col1, #T_ebbcc_row11_col2, #T_ebbcc_row11_col3, #T_ebbcc_row11_col4, #T_ebbcc_row11_col5, #T_ebbcc_row11_col6, #T_ebbcc_row11_col7, #T_ebbcc_row12_col0, #T_ebbcc_row12_col1, #T_ebbcc_row12_col2, #T_ebbcc_row12_col3, #T_ebbcc_row12_col4, #T_ebbcc_row12_col5, #T_ebbcc_row12_col6, #T_ebbcc_row12_col7, #T_ebbcc_row13_col0, #T_ebbcc_row13_col1, #T_ebbcc_row13_col2, #T_ebbcc_row13_col4 {
#   text-align: left;
# }
# #T_ebbcc_row0_col1, #T_ebbcc_row0_col2, #T_ebbcc_row0_col4, #T_ebbcc_row13_col3, #T_ebbcc_row13_col5, #T_ebbcc_row13_col6, #T_ebbcc_row13_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ebbcc_row0_col8, #T_ebbcc_row1_col8, #T_ebbcc_row2_col8, #T_ebbcc_row3_col8, #T_ebbcc_row5_col8, #T_ebbcc_row6_col8, #T_ebbcc_row7_col8, #T_ebbcc_row8_col8, #T_ebbcc_row9_col8, #T_ebbcc_row10_col8, #T_ebbcc_row11_col8, #T_ebbcc_row12_col8, #T_ebbcc_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ebbcc_row4_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ebbcc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebbcc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ebbcc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ebbcc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ebbcc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ebbcc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ebbcc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ebbcc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ebbcc_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ebbcc_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebbcc_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_ebbcc_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ebbcc_row0_col1" class="data row0 col1" >0.8796</td>
#       <td id="T_ebbcc_row0_col2" class="data row0 col2" >0.8703</td>
#       <td id="T_ebbcc_row0_col3" class="data row0 col3" >0.0541</td>
#       <td id="T_ebbcc_row0_col4" class="data row0 col4" >0.5737</td>
#       <td id="T_ebbcc_row0_col5" class="data row0 col5" >0.0988</td>
#       <td id="T_ebbcc_row0_col6" class="data row0 col6" >0.0794</td>
#       <td id="T_ebbcc_row0_col7" class="data row0 col7" >0.1487</td>
#       <td id="T_ebbcc_row0_col8" class="data row0 col8" >122.3070</td>
#     </tr>
#     <tr>
#       <th id="T_ebbcc_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_ebbcc_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ebbcc_row1_col1" class="data row1 col1" >0.8780</td>
#       <td id="T_ebbcc_row1_col2" class="data row1 col2" >0.8648</td>
#       <td id="T_ebbcc_row1_col3" class="data row1 col3" >0.0027</td>
#       <td id="T_ebbcc_row1_col4" class="data row1 col4" >0.5156</td>
#       <td id="T_ebbcc_row1_col5" class="data row1 col5" >0.0055</td>
#       <td id="T_ebbcc_row1_col6" class="data row1 col6" >0.0042</td>
#       <td id="T_ebbcc_row1_col7" class="data row1 col7" >0.0306</td>
#       <td id="T_ebbcc_row1_col8" class="data row1 col8" >3.9370</td>
#     </tr>
#     <tr>
#       <th id="T_ebbcc_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_ebbcc_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_ebbcc_row2_col1" class="data row2 col1" >0.8780</td>
#       <td id="T_ebbcc_row2_col2" class="data row2 col2" >0.8605</td>
#       <td id="T_ebbcc_row2_col3" class="data row2 col3" >0.0087</td>
#       <td id="T_ebbcc_row2_col4" class="data row2 col4" >0.5050</td>
#       <td id="T_ebbcc_row2_col5" class="data row2 col5" >0.0172</td>
#       <td id="T_ebbcc_row2_col6" class="data row2 col6" >0.0131</td>
#       <td id="T_ebbcc_row2_col7" class="data row2 col7" >0.0536</td>
#       <td id="T_ebbcc_row2_col8" class="data row2 col8" >1.3150</td>
#     </tr>
#     <tr>
#       <th id="T_ebbcc_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_ebbcc_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_ebbcc_row3_col1" class="data row3 col1" >0.8779</td>
#       <td id="T_ebbcc_row3_col2" class="data row3 col2" >0.8457</td>
#       <td id="T_ebbcc_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_ebbcc_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_ebbcc_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_ebbcc_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_ebbcc_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_ebbcc_row3_col8" class="data row3 col8" >0.2560</td>
#     </tr>
#     <tr>
#       <th id="T_ebbcc_level0_row4" class="row_heading level0 row4" >dummy</th>
#       <td id="T_ebbcc_row4_col0" class="data row4 col0" >Dummy Classifier</td>
#       <td id="T_ebbcc_row4_col1" class="data row4 col1" >0.8779</td>
#       <td id="T_ebbcc_row4_col2" class="data row4 col2" >0.5000</td>
#       <td id="T_ebbcc_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_ebbcc_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_ebbcc_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_ebbcc_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_ebbcc_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_ebbcc_row4_col8" class="data row4 col8" >0.2420</td>
#     </tr>
#     <tr>
#       <th id="T_ebbcc_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_ebbcc_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_ebbcc_row5_col1" class="data row5 col1" >0.8776</td>
#       <td id="T_ebbcc_row5_col2" class="data row5 col2" >0.8428</td>
#       <td id="T_ebbcc_row5_col3" class="data row5 col3" >0.0005</td>
#       <td id="T_ebbcc_row5_col4" class="data row5 col4" >0.1674</td>
#       <td id="T_ebbcc_row5_col5" class="data row5 col5" >0.0010</td>
#       <td id="T_ebbcc_row5_col6" class="data row5 col6" >0.0002</td>
#       <td id="T_ebbcc_row5_col7" class="data row5 col7" >0.0023

# %%
# Create and train a model (e.g., Random Forest)
model = create_model('rf')
# Out:
# <style type="text/css">
# #T_c90e9_row10_col0, #T_c90e9_row10_col1, #T_c90e9_row10_col2, #T_c90e9_row10_col3, #T_c90e9_row10_col4, #T_c90e9_row10_col5, #T_c90e9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c90e9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c90e9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c90e9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c90e9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c90e9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c90e9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c90e9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c90e9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c90e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c90e9_row0_col0" class="data row0 col0" >0.8687</td>
#       <td id="T_c90e9_row0_col1" class="data row0 col1" >0.8428</td>
#       <td id="T_c90e9_row0_col2" class="data row0 col2" >0.1408</td>
#       <td id="T_c90e9_row0_col3" class="data row0 col3" >0.3936</td>
#       <td id="T_c90e9_row0_col4" class="data row0 col4" >0.2074</td>
#       <td id="T_c90e9_row0_col5" class="data row0 col5" >0.1529</td>
#       <td id="T_c90e9_row0_col6" class="data row0 col6" >0.1773</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c90e9_row1_col0" class="data row1 col0" >0.8682</td>
#       <td id="T_c90e9_row1_col1" class="data row1 col1" >0.8403</td>
#       <td id="T_c90e9_row1_col2" class="data row1 col2" >0.1403</td>
#       <td id="T_c90e9_row1_col3" class="data row1 col3" >0.3896</td>
#       <td id="T_c90e9_row1_col4" class="data row1 col4" >0.2063</td>
#       <td id="T_c90e9_row1_col5" class="data row1 col5" >0.1515</td>
#       <td id="T_c90e9_row1_col6" class="data row1 col6" >0.1752</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c90e9_row2_col0" class="data row2 col0" >0.8713</td>
#       <td id="T_c90e9_row2_col1" class="data row2 col1" >0.8469</td>
#       <td id="T_c90e9_row2_col2" class="data row2 col2" >0.1427</td>
#       <td id="T_c90e9_row2_col3" class="data row2 col3" >0.4203</td>
#       <td id="T_c90e9_row2_col4" class="data row2 col4" >0.2131</td>
#       <td id="T_c90e9_row2_col5" class="data row2 col5" >0.1611</td>
#       <td id="T_c90e9_row2_col6" class="data row2 col6" >0.1894</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c90e9_row3_col0" class="data row3 col0" >0.8687</td>
#       <td id="T_c90e9_row3_col1" class="data row3 col1" >0.8430</td>
#       <td id="T_c90e9_row3_col2" class="data row3 col2" >0.1337</td>
#       <td id="T_c90e9_row3_col3" class="data row3 col3" >0.3902</td>
#       <td id="T_c90e9_row3_col4" class="data row3 col4" >0.1991</td>
#       <td id="T_c90e9_row3_col5" class="data row3 col5" >0.1459</td>
#       <td id="T_c90e9_row3_col6" class="data row3 col6" >0.1711</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c90e9_row4_col0" class="data row4 col0" >0.8705</td>
#       <td id="T_c90e9_row4_col1" class="data row4 col1" >0.8482</td>
#       <td id="T_c90e9_row4_col2" class="data row4 col2" >0.1478</td>
#       <td id="T_c90e9_row4_col3" class="data row4 col3" >0.4147</td>
#       <td id="T_c90e9_row4_col4" class="data row4 col4" >0.2179</td>
#       <td id="T_c90e9_row4_col5" class="data row4 col5" >0.1643</td>
#       <td id="T_c90e9_row4_col6" class="data row4 col6" >0.1906</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c90e9_row5_col0" class="data row5 col0" >0.8681</td>
#       <td id="T_c90e9_row5_col1" class="data row5 col1" >0.8470</td>
#       <td id="T_c90e9_row5_col2" class="data row5 col2" >0.1333</td>
#       <td id="T_c90e9_row5_col3" class="data row5 col3" >0.3842</td>
#       <td id="T_c90e9_row5_col4" class="data row5 col4" >0.1979</td>
#       <td id="T_c90e9_row5_col5" class="data row5 col5" >0.1441</td>
#       <td id="T_c90e9_row5_col6" class="data row5 col6" >0.1684</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c90e9_row6_col0" class="data row6 col0" >0.8681</td>
#       <td id="T_c90e9_row6_col1" class="data row6 col1" >0.8497</td>
#       <td id="T_c90e9_row6_col2" class="data row6 col2" >0.1282</td>
#       <td id="T_c90e9_row6_col3" class="data row6 col3" >0.3807</td>
#       <td id="T_c90e9_row6_col4" class="data row6 col4" >0.1918</td>
#       <td id="T_c90e9_row6_col5" class="data row6 col5" >0.1388</td>
#       <td id="T_c90e9_row6_col6" class="data row6 col6" >0.1635</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c90e9_row7_col0" class="data row7 col0" >0.8689</td>
#       <td id="T_c90e9_row7_col1" class="data row7 col1" >0.8468</td>
#       <td id="T_c90e9_row7_col2" class="data row7 col2" >0.1392</td>
#       <td id="T_c90e9_row7_col3" class="data row7 col3" >0.3953</td>
#       <td id="T_c90e9_row7_col4" class="data row7 col4" >0.2059</td>
#       <td id="T_c90e9_row7_col5" class="data row7 col5" >0.1519</td>
#       <td id="T_c90e9_row7_col6" class="data row7 col6" >0.1769</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c90e9_row8_col0" class="data row8 col0" >0.8662</td>
#       <td id="T_c90e9_row8_col1" class="data row8 col1" >0.8384</td>
#       <td id="T_c90e9_row8_col2" class="data row8 col2" >0.1301</td>
#       <td id="T_c90e9_row8_col3" class="data row8 col3" >0.3652</td>
#       <td id="T_c90e9_row8_col4" class="data row8 col4" >0.1919</td>
#       <td id="T_c90e9_row8_col5" class="data row8 col5" >0.1365</td>
#       <td id="T_c90e9_row8_col6" class="data row8 col6" >0.1584</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c90e9_row9_col0" class="data row9 col0" >0.8670</td>
#       <td id="T_c90e9_row9_col1" class="data row9 col1" >0.8402</td>
#       <td id="T_c90e9_row9_col2" class="data row9 col2" >0.1446</td>
#       <td id="T_c90e9_row9_col3" class="data row9 col3" >0.3820</td>
#       <td id="T_c90e9_row9_col4" class="data row9 col4" >0.2098</td>
#       <td id="T_c90e9_row9_col5" class="data row9 col5" >0.1530</td>
#       <td id="T_c90e9_row9_col6" class="data row9 col6" >0.1748</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c90e9_row10_col0" class="data row10 col0" >0.8686</td>
#       <td id="T_c90e9_row10_col1" class="data row10 col1" >0.8443</td>
#       <td id="T_c90e9_row10_col2" class="data row10 col2" >0.1381</td>
#       <td id="T_c90e9_row10_col3" class="data row10 col3" >0.3916</td>
#       <td id="T_c90e9_row10_col4" class="data row10 col4" >0.2041</td>
#       <td id="T_c90e9_row10_col5" class="data row10 col5" >0.1500</td>
#       <td id="T_c90e9_row10_col6" class="data row10 col6" >0.1746</td>
#     </tr>
#     <tr>
#       <th id="T_c90e9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c90e9_row11_col0" class="data row11 col0" >0.0014</td>
#       <td id="T_c90e9_row11_col1" class="data row11 col1" >0.0037</td>
#       <td id="T_c90e9_row11_col2" class="data row11 col2" >0.0061</td>
#       <td id="T_c90e9_row11_col3" class="data row11 col3" >0.0153</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# Evaluate the model
evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Make predictions on the test data
predictions = predict_model(model, data=df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b9f68" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9f68_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b9f68_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b9f68_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b9f68_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b9f68_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b9f68_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b9f68_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b9f68_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9f68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9f68_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_b9f68_row0_col1" class="data row0 col1" >0.8123</td>
#       <td id="T_b9f68_row0_col2" class="data row0 col2" >0.4996</td>
#       <td id="T_b9f68_row0_col3" class="data row0 col3" >0.0856</td>
#       <td id="T_b9f68_row0_col4" class="data row0 col4" >0.1208</td>
#       <td id="T_b9f68_row0_col5" class="data row0 col5" >0.1002</td>
#       <td id="T_b9f68_row0_col6" class="data row0 col6" >-0.0012</td>
#       <td id="T_b9f68_row0_col7" class="data row0 col7" >-0.0012</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Results**
#
# The results indicate that the Light Gradient Boosting Machine is the best-performing model, with an accuracy of 0.8796 and an AUC of 0.8703. These values suggest that this model is highly effective in reliably identifying positive cases (customers interested in additional insurance). In comparison, the Gradient Boosting Classifier achieved a similar accuracy of 0.8780, while the Ada Boost Classifier and Ridge Classifier showed slightly lower values.
#
# The average performance across all folds highlights the stability of the models. The Random Forest Classifier performed the weakest, with an accuracy of 0.8123 and an AUC of 0.4996, indicating that it is not well-suited for this particular application.

# %% [markdown]
# **Conclusion**
#
# In summary, the analysis demonstrates that the Light Gradient Boosting Machine is the most effective model for binary classification in the context of insurance cross-selling. The results suggest that companies looking to target their offers to interested customers could benefit from implementing this model. Future work could focus on integrating additional features and improving data quality to further enhance predictive accuracy.
