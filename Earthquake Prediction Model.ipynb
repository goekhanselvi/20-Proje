# %% [markdown]
# # **Earthquake Prediction Model**

# %% [markdown]
# Earthquake prediction models are vital tools for forecasting seismic events and minimizing their impact. These models analyze historical earthquake data, geological information, and real-time seismic activity to identify patterns.

# %% [markdown]
# **Data Dictionary**
#
# | Column Name                                   | Description                                                             |
# |-----------------------------------------------|-------------------------------------------------------------------------|
# | Date                                          | Date of the seismic event                                               |
# | Time                                          | Time of the seismic event                                               |
# | Latitude                                      | Latitude coordinate of the event location                               |
# | Longitude                                     | Longitude coordinate of the event location                              |
# | Type                                          | Type of seismic event (e.g., earthquake, explosion)                    |
# | Depth                                         | Depth of the seismic event in kilometers                                |
# | Depth Error                                   | Error in the depth measurement                                          |
# | Depth Seismic Stations                        | Number of seismic stations used for depth measurement                   |
# | Magnitude                                     | Magnitude of the seismic event                                          |
# | Magnitude Type                                | Type of magnitude measurement (e.g., moment magnitude)                 |
# | Magnitude Error                               | Error in the magnitude measurement                                       |
# | Magnitude Seismic Stations                    | Number of seismic stations used for magnitude measurement               |
# | Azimuthal Gap                                 | Azimuthal gap in degrees                                               |
# | Horizontal Distance                           | Horizontal distance from the event location in kilometers                |
# | Horizontal Error                              | Error in the horizontal distance measurement                            |
# | Root Mean Square                              | Root mean square value of the seismic event                             |
# | ID                                            | Unique identifier for the seismic event                                 |
# | Source                                        | Data source of the seismic event                                        |
# | Location Source                               | Source of the location information                                      |
# | Magnitude Source                              | Source of the magnitude information                                      |
# | Status                                        | Status of the seismic event (e.g., confirmed, reviewed)                |

# %% [markdown]
# <img src='https://pfst.cf2.poecdn.net/base/image/4557fdd31d42cc4c5de5c929bff2948251b4ec0eb2618e01cbd9322c9f7f3ea3?w=1024&h=768&pmaid=254399078' width='900'>
# <a href='https://thecleverprogrammer.com/2020/11/12/earthquake-prediction-model-with-machine-learning/' target=_blank>
# Click here for the dataset </a>

# %% [markdown]
# **Import library**

# %%
#!pip install pycaret

# %%
import pandas as pd
pd.set_option("display.max_columns",55)

import warnings
warnings.filterwarnings("ignore")

# %%
from pycaret.regression import *

# %%
df=pd.read_csv('database.csv')

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  Magnitude Error  \
# 0                     NaN        6.0             MW              NaN
# 1                     NaN        5.8             MW              NaN
# 2                     NaN        6.2             MW              NaN
# 3                     NaN        5.8             MW              NaN
# 4                     NaN        5.8             MW              NaN
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic

# %% [markdown]
# **Modelling**

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_98c87 th {
#   text-align: left;
# }
# #T_98c87_row0_col0, #T_98c87_row0_col6, #T_98c87_row1_col0, #T_98c87_row1_col1, #T_98c87_row1_col2, #T_98c87_row1_col3, #T_98c87_row1_col4, #T_98c87_row1_col5, #T_98c87_row1_col6, #T_98c87_row2_col0, #T_98c87_row2_col1, #T_98c87_row2_col2, #T_98c87_row2_col3, #T_98c87_row2_col4, #T_98c87_row2_col5, #T_98c87_row2_col6, #T_98c87_row3_col0, #T_98c87_row3_col1, #T_98c87_row3_col2, #T_98c87_row3_col3, #T_98c87_row3_col4, #T_98c87_row3_col5, #T_98c87_row3_col6, #T_98c87_row4_col0, #T_98c87_row4_col1, #T_98c87_row4_col2, #T_98c87_row4_col3, #T_98c87_row4_col4, #T_98c87_row4_col5, #T_98c87_row4_col6, #T_98c87_row5_col0, #T_98c87_row5_col1, #T_98c87_row5_col2, #T_98c87_row5_col3, #T_98c87_row5_col4, #T_98c87_row5_col5, #T_98c87_row5_col6, #T_98c87_row6_col0, #T_98c87_row6_col1, #T_98c87_row6_col2, #T_98c87_row6_col3, #T_98c87_row6_col4, #T_98c87_row6_col5, #T_98c87_row6_col6, #T_98c87_row7_col0, #T_98c87_row7_col1, #T_98c87_row7_col2, #T_98c87_row7_col3, #T_98c87_row7_col4, #T_98c87_row7_col5, #T_98c87_row7_col6, #T_98c87_row8_col0, #T_98c87_row8_col1, #T_98c87_row8_col2, #T_98c87_row8_col3, #T_98c87_row8_col4, #T_98c87_row8_col5, #T_98c87_row8_col6, #T_98c87_row9_col0, #T_98c87_row9_col1, #T_98c87_row9_col2, #T_98c87_row9_col3, #T_98c87_row9_col4, #T_98c87_row9_col5, #T_98c87_row9_col6, #T_98c87_row10_col0, #T_98c87_row10_col1, #T_98c87_row10_col2, #T_98c87_row10_col3, #T_98c87_row10_col4, #T_98c87_row10_col5, #T_98c87_row10_col6, #T_98c87_row11_col0, #T_98c87_row11_col1, #T_98c87_row11_col2, #T_98c87_row11_col3, #T_98c87_row11_col4, #T_98c87_row11_col5, #T_98c87_row12_col0, #T_98c87_row12_col1, #T_98c87_row12_col2, #T_98c87_row12_col3, #T_98c87_row12_col4, #T_98c87_row12_col5, #T_98c87_row12_col6, #T_98c87_row13_col0, #T_98c87_row13_col1, #T_98c87_row13_col2, #T_98c87_row13_col3, #T_98c87_row13_col4, #T_98c87_row13_col5, #T_98c87_row13_col6, #T_98c87_row14_col0, #T_98c87_row14_col1, #T_98c87_row14_col2, #T_98c87_row14_col3, #T_98c87_row14_col4, #T_98c87_row14_col5, #T_98c87_row14_col6, #T_98c87_row15_col0, #T_98c87_row15_col1, #T_98c87_row15_col2, #T_98c87_row15_col3, #T_98c87_row15_col4, #T_98c87_row15_col5, #T_98c87_row15_col6, #T_98c87_row16_col0, #T_98c87_row16_col1, #T_98c87_row16_col2, #T_98c87_row16_col3, #T_98c87_row16_col4, #T_98c87_row16_col5, #T_98c87_row16_col6, #T_98c87_row17_col0, #T_98c87_row17_col1, #T_98c87_row17_col2, #T_98c87_row17_col3, #T_98c87_row17_col4, #T_98c87_row17_col5, #T_98c87_row17_col6 {
#   text-align: left;
# }
# #T_98c87_row0_col1, #T_98c87_row0_col2, #T_98c87_row0_col3, #T_98c87_row0_col4, #T_98c87_row0_col5, #T_98c87_row11_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_98c87_row0_col7, #T_98c87_row1_col7, #T_98c87_row2_col7, #T_98c87_row3_col7, #T_98c87_row4_col7, #T_98c87_row5_col7, #T_98c87_row6_col7, #T_98c87_row7_col7, #T_98c87_row8_col7, #T_98c87_row9_col7, #T_98c87_row10_col7, #T_98c87_row11_col7, #T_98c87_row12_col7, #T_98c87_row13_col7, #T_98c87_row15_col7, #T_98c87_row16_col7, #T_98c87_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_98c87_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_98c87">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98c87_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_98c87_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_98c87_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_98c87_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_98c87_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_98c87_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_98c87_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_98c87_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98c87_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_98c87_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_98c87_row0_col1" class="data row0 col1" >2701.9927</td>
#       <td id="T_98c87_row0_col2" class="data row0 col2" >23548981.3626</td>
#       <td id="T_98c87_row0_col3" class="data row0 col3" >4832.9682</td>
#       <td id="T_98c87_row0_col4" class="data row0 col4" >0.8320</td>
#       <td id="T_98c87_row0_col5" class="data row0 col5" >0.4447</td>
#       <td id="T_98c87_row0_col6" class="data row0 col6" >0.3137</td>
#       <td id="T_98c87_row0_col7" class="data row0 col7" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_98c87_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_98c87_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_98c87_row1_col1" class="data row1 col1" >2771.4583</td>
#       <td id="T_98c87_row1_col2" class="data row1 col2" >25416502.3827</td>
#       <td id="T_98c87_row1_col3" class="data row1 col3" >5028.6343</td>
#       <td id="T_98c87_row1_col4" class="data row1 col4" >0.8172</td>
#       <td id="T_98c87_row1_col5" class="data row1 col5" >0.4690</td>
#       <td id="T_98c87_row1_col6" class="data row1 col6" >0.3303</td>
#       <td id="T_98c87_row1_col7" class="data row1 col7" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_98c87_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_98c87_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_98c87_row2_col1" class="data row2 col1" >2992.1828</td>
#       <td id="T_98c87_row2_col2" class="data row2 col2" >25521038.3331</td>
#       <td id="T_98c87_row2_col3" class="data row2 col3" >5042.0978</td>
#       <td id="T_98c87_row2_col4" class="data row2 col4" >0.8149</td>
#       <td id="T_98c87_row2_col5" class="data row2 col5" >0.5378</td>
#       <td id="T_98c87_row2_col6" class="data row2 col6" >0.3751</td>
#       <td id="T_98c87_row2_col7" class="data row2 col7" >0.1150</td>
#     </tr>
#     <tr>
#       <th id="T_98c87_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_98c87_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_98c87_row3_col1" class="data row3 col1" >2833.3624</td>
#       <td id="T_98c87_row3_col2" class="data row3 col2" >28427844.2412</td>
#       <td id="T_98c87_row3_col3" class="data row3 col3" >5305.6516</td>
#       <td id="T_98c87_row3_col4" class="data row3 col4" >0.7991</td>
#       <td id="T_98c87_row3_col5" class="data row3 col5" >0.4877</td>
#       <td id="T_98c87_row3_col6" class="data row3 col6" >0.3363</td>
#       <td id="T_98c87_row3_col7" class="data row3 col7" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_98c87_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_98c87_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_98c87_row4_col1" class="data row4 col1" >4316.0568</td>
#       <td id="T_98c87_row4_col2" class="data row4 col2" >29220505.6498</td>
#       <td id="T_98c87_row4_col3" class="data row4 col3" >5398.4561</td>
#       <td id="T_98c87_row4_col4" class="data row4 col4" >0.7903</td>
#       <td id="T_98c87_row4_col5" class="data row4 col5" >0.6368</td>
#       <td id="T_98c87_row4_col6" class="data row4 col6" >0.7394</td>
#       <td id="T_98c87_row4_col7" class="data row4 col7" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_98c87_level0_row5" class="row_heading level0 row5" >lar</th>
#       <td id="T_98c87_row5_col0" class="data row5 col0" >Least Angle Regression</td>
#       <td id="T_98c87_row5_col1" class="data row5 col1" >4303.5559</td>
#       <td id="T_98c87_row5_col2" class="data row5 col2" >38388058.4578</td>
#       <td id="T_98c87_row5_col3" class="data row5 col3" >6176.5920</td>
#       <td id="T_98c87_row5_col4" class="data row5 col4" >0.7306</td>
#       <td id="T_98c87_row5_col5" class="data row5 col5" >0.5949</td>
#       <td id="T_98c87_row5_col6" class="data row5 col6" >0.4433</td>
#       <td id="T_98c87_row5_col7" class="

# %%
#  	Gradient Boosting Regressor ile R² 0.8320.

# %%
from pycaret.classification import*

# %%
setup(df, target='Status')
# Out:
# <style type="text/css">
# #T_86b0d_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_86b0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86b0d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_86b0d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86b0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86b0d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_86b0d_row0_col1" class="data row0 col1" >2317</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86b0d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_86b0d_row1_col1" class="data row1 col1" >Status</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_86b0d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_86b0d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_86b0d_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_86b0d_row3_col1" class="data row3 col1" >Automatic: 0, Reviewed: 1</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_86b0d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_86b0d_row4_col1" class="data row4 col1" >(23412, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_86b0d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_86b0d_row5_col1" class="data row5 col1" >(23412, 68)</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_86b0d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_86b0d_row6_col1" class="data row6 col1" >(16388, 68)</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_86b0d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_86b0d_row7_col1" class="data row7 col1" >(7024, 68)</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_86b0d_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_86b0d_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_86b0d_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_86b0d_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_86b0d_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_86b0d_row10_col1" class="data row10 col1" >99.9%</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_86b0d_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_86b0d_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_86b0d_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_86b0d_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_86b0d_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_86b0d_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_86b0d_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_86b0d_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_86b0d_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_86b0d_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_86b0d_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_86b0d_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_86b0d_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_86b0d_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_86b0d_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_86b0d_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_86b0d_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_86b0d_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_86b0d_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_86b0d_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_86b0d_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_86b0d_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_86b0d_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_86b0d_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_86b0d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_86b0d_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_86b0d_row23_col1" class="data row23 col1" >2e0d</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_298ad th {
#   text-align: left;
# }
# #T_298ad_row0_col0, #T_298ad_row1_col0, #T_298ad_row1_col1, #T_298ad_row1_col2, #T_298ad_row1_col3, #T_298ad_row1_col4, #T_298ad_row1_col5, #T_298ad_row1_col6, #T_298ad_row1_col7, #T_298ad_row2_col0, #T_298ad_row2_col1, #T_298ad_row2_col3, #T_298ad_row2_col4, #T_298ad_row2_col5, #T_298ad_row2_col6, #T_298ad_row2_col7, #T_298ad_row3_col0, #T_298ad_row3_col1, #T_298ad_row3_col3, #T_298ad_row3_col4, #T_298ad_row3_col5, #T_298ad_row3_col6, #T_298ad_row3_col7, #T_298ad_row4_col0, #T_298ad_row4_col1, #T_298ad_row4_col3, #T_298ad_row4_col4, #T_298ad_row4_col5, #T_298ad_row4_col6, #T_298ad_row4_col7, #T_298ad_row5_col0, #T_298ad_row5_col1, #T_298ad_row5_col3, #T_298ad_row5_col4, #T_298ad_row5_col5, #T_298ad_row5_col6, #T_298ad_row5_col7, #T_298ad_row6_col0, #T_298ad_row6_col1, #T_298ad_row6_col2, #T_298ad_row6_col3, #T_298ad_row6_col4, #T_298ad_row6_col5, #T_298ad_row6_col6, #T_298ad_row6_col7, #T_298ad_row7_col0, #T_298ad_row7_col1, #T_298ad_row7_col2, #T_298ad_row7_col3, #T_298ad_row7_col4, #T_298ad_row7_col5, #T_298ad_row7_col6, #T_298ad_row7_col7, #T_298ad_row8_col0, #T_298ad_row8_col1, #T_298ad_row8_col2, #T_298ad_row8_col3, #T_298ad_row8_col4, #T_298ad_row8_col5, #T_298ad_row8_col6, #T_298ad_row8_col7, #T_298ad_row9_col0, #T_298ad_row9_col1, #T_298ad_row9_col2, #T_298ad_row9_col3, #T_298ad_row9_col4, #T_298ad_row9_col5, #T_298ad_row9_col6, #T_298ad_row9_col7, #T_298ad_row10_col0, #T_298ad_row10_col1, #T_298ad_row10_col2, #T_298ad_row10_col3, #T_298ad_row10_col4, #T_298ad_row10_col5, #T_298ad_row10_col6, #T_298ad_row10_col7, #T_298ad_row11_col0, #T_298ad_row11_col1, #T_298ad_row11_col2, #T_298ad_row11_col3, #T_298ad_row11_col4, #T_298ad_row11_col5, #T_298ad_row11_col6, #T_298ad_row11_col7, #T_298ad_row12_col0, #T_298ad_row12_col1, #T_298ad_row12_col2, #T_298ad_row12_col3, #T_298ad_row12_col4, #T_298ad_row12_col5, #T_298ad_row12_col6, #T_298ad_row12_col7, #T_298ad_row13_col0, #T_298ad_row13_col1, #T_298ad_row13_col2, #T_298ad_row13_col3, #T_298ad_row13_col4, #T_298ad_row13_col5, #T_298ad_row13_col6, #T_298ad_row13_col7 {
#   text-align: left;
# }
# #T_298ad_row0_col1, #T_298ad_row0_col2, #T_298ad_row0_col3, #T_298ad_row0_col4, #T_298ad_row0_col5, #T_298ad_row0_col6, #T_298ad_row0_col7, #T_298ad_row2_col2, #T_298ad_row3_col2, #T_298ad_row4_col2, #T_298ad_row5_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_298ad_row0_col8, #T_298ad_row1_col8, #T_298ad_row2_col8, #T_298ad_row3_col8, #T_298ad_row4_col8, #T_298ad_row5_col8, #T_298ad_row6_col8, #T_298ad_row7_col8, #T_298ad_row9_col8, #T_298ad_row10_col8, #T_298ad_row11_col8, #T_298ad_row12_col8, #T_298ad_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_298ad_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_298ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_298ad_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_298ad_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_298ad_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_298ad_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_298ad_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_298ad_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_298ad_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_298ad_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_298ad_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_298ad_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_298ad_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_298ad_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_298ad_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_298ad_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_298ad_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_298ad_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_298ad_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_298ad_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_298ad_row0_col8" class="data row0 col8" >0.5370</td>
#     </tr>
#     <tr>
#       <th id="T_298ad_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_298ad_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_298ad_row1_col1" class="data row1 col1" >0.9999</td>
#       <td id="T_298ad_row1_col2" class="data row1 col2" >0.9997</td>
#       <td id="T_298ad_row1_col3" class="data row1 col3" >0.9999</td>
#       <td id="T_298ad_row1_col4" class="data row1 col4" >0.9999</td>
#       <td id="T_298ad_row1_col5" class="data row1 col5" >0.9999</td>
#       <td id="T_298ad_row1_col6" class="data row1 col6" >0.9997</td>
#       <td id="T_298ad_row1_col7" class="data row1 col7" >0.9997</td>
#       <td id="T_298ad_row1_col8" class="data row1 col8" >0.1000</td>
#     </tr>
#     <tr>
#       <th id="T_298ad_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_298ad_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_298ad_row2_col1" class="data row2 col1" >0.9999</td>
#       <td id="T_298ad_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_298ad_row2_col3" class="data row2 col3" >0.9999</td>
#       <td id="T_298ad_row2_col4" class="data row2 col4" >0.9999</td>
#       <td id="T_298ad_row2_col5" class="data row2 col5" >0.9999</td>
#       <td id="T_298ad_row2_col6" class="data row2 col6" >0.9997</td>
#       <td id="T_298ad_row2_col7" class="data row2 col7" >0.9997</td>
#       <td id="T_298ad_row2_col8" class="data row2 col8" >0.1020</td>
#     </tr>
#     <tr>
#       <th id="T_298ad_level0_row3" class="row_heading level0 row3" >qda</th>
#       <td id="T_298ad_row3_col0" class="data row3 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_298ad_row3_col1" class="data row3 col1" >0.9999</td>
#       <td id="T_298ad_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_298ad_row3_col3" class="data row3 col3" >0.9999</td>
#       <td id="T_298ad_row3_col4" class="data row3 col4" >0.9999</td>
#       <td id="T_298ad_row3_col5" class="data row3 col5" >0.9999</td>
#       <td id="T_298ad_row3_col6" class="data row3 col6" >0.9997</td>
#       <td id="T_298ad_row3_col7" class="data row3 col7" >0.9997</td>
#       <td id="T_298ad_row3_col8" class="data row3 col8" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_298ad_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_298ad_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_298ad_row4_col1" class="data row4 col1" >0.9991</td>
#       <td id="T_298ad_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_298ad_row4_col3" class="data row4 col3" >0.9991</td>
#       <td id="T_298ad_row4_col4" class="data row4 col4" >0.9991</td>
#       <td id="T_298ad_row4_col5" class="data row4 col5" >0.9991</td>
#       <td id="T_298ad_row4_col6" class="data row4 col6" >0.9954</td>
#       <td id="T_298ad_row4_col7" class="data row4 col7" >0.9954</td>
#       <td id="T_298ad_row4_col8" class="data row4 col8" >0.1480</td>
#     </tr>
#     <tr>
#       <th id="T_298ad_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_298ad_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_298ad_row5_col1" class="data row5 col1" >0.9979</td>
#       <td id="T_298ad_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_298ad_row5_col3" class="data row5 col3" >0.9979</td>
#       <td id="T_298ad_row5_col4" class="data row5 col4" >0.9979</td>
#       <td id="T_298ad_row5_col5" class="data row5 col5" >0.9979</td>
#       <td id="T_298ad_row5_col6" class="data row5 col6" >0.9895</td>
#       <td id="T_298ad_row5_col7" class="data row5 col7" >0.9896</td>
#       <td id="T_298ad_row5_col8
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=2317, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Naive Bayes Accuracy ~ 0.9999
